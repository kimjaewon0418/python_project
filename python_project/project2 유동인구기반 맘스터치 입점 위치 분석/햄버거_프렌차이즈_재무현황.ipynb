# %%
import pandas as pd

# %%
a = pd.read_excel('/content/롯데리아 재무현황.xlsx')

# %%
a
# Out:
#       LABEL-1        자본금       자본금 합계         매출 액     매출 전체 이익        영업 이익  \
# 0  2023.12.31  1,260,765  175,608,023  906,047,416  463,299,632   21,104,795
# 1  2022.12.31  1,260,765  186,628,158  773,300,007  371,790,518    5,319,696
# 2  2021.12.31  1,260,765  182,638,689  674,804,630  337,346,362  -22,280,014
#
#   전체 자산 증가 율 매출 액 증가 율 매출 액 순이익 률 영업 이익 율
# 0     -7.67%    17.17%      0.31%   2.33%
# 1      9.64%    14.60%     -1.15%   0.69%
# 2    -11.03%     1.70%     -6.00%  -3.30%

# %%
b = pd.read_excel('/content/맘스터치 재무현황.xlsx')

# %%
b
# Out:
#       LABEL-1         자본금      자본금 합계         매출 액     매출 전체 이익       영업 이익  \
# 0  2023.12.31   4,147,270  46,733,193  363,968,166  118,292,735  54,627,701
# 1  2022.12.31  10,181,753  91,910,912  331,864,104  103,975,003  47,640,450
# 2  2021.12.31  10,181,753  85,157,221  301,140,564  100,426,494  38,579,242
#
#   매출 액 증가 율 매출 액 순이익 률 영업 이익 율
# 0     9.67%     11.51%  15.01%
# 1    10.20%      8.65%  14.36%
# 2     5.52%      9.31%  12.81%

# %%
c = pd.read_excel('/content/맥도날드 재무현황.xlsx')

# %%
c
# Out:
#       LABEL-1         자본금       자본금 합계           매출 액     매출 전체 이익  \
# 0  2023.12.31  70,128,500  224,988,758  1,118,061,233  702,809,947
# 1  2022.12.31  69,915,120   42,759,230    994,617,092  623,301,234
# 2  2021.12.31  69,915,120   78,304,004    867,872,276  556,560,498
#
#          영업 이익 전체 자산 증가 율 매출 액 증가 율 매출 액 순이익 률 영업 이익 율
# 0  -20,283,011      3.70%    12.41%     -2.85%  -1.81%
# 1  -27,778,807      2.91%    14.60%     -3.65%  -2.79%
# 2  -27,753,739     -0.98%     9.72%     -4.03%  -3.20%

# %%
d = pd.read_excel('/content/서브웨이 재무현황.xlsx')

# %%
d
# Out:
#       LABEL-1 자본금      자본금 합계        매출 액    매출 전체 이익       영업 이익 전체 자산 증가 율  \
# 0  2023.12.31   -  23,826,046  40,523,401  40,523,401  20,018,608    -22.42%
# 1  2022.12.31   -  40,565,417  33,776,303  33,776,303  15,537,540     40.84%
# 2  2021.12.31   -  27,087,843  26,206,738  26,206,738   8,546,445     40.65%
#
#   매출 액 증가 율 매출 액 순이익 률 영업 이익 율
# 0    19.98%     25.32%  49.40%
# 1    28.88%     36.02%  46.00%
# 2     4.51%     24.13%  32.61%
